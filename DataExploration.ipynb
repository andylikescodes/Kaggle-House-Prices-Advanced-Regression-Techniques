# %% [markdown]
# # A List of Parameters
#
# <a id="idTop"></a>
#
# 1. +**[MSSubClass](#idMSSubClass)
# 2. +**[MSZoning](#idMSZoning)
# 3. *~[LotFrontage](#idLotFrontage)-0.17 Missing
# 4. [LotArea](#idLotArea)
# 5. [Street](#idStreet)
# 6. ~[Alley](#idAlley)-0.93 Missing
# 7. [LotShape](#idLotShape)
# 8. -*[LandContour](#idLandContour)
# 9. -*[Utilities](#idUtilities)
# 10. [LotConfig](#idLotConfig)
# 11. [LandSlope](#idLandSlope)
# 12. ++**[Neighborhood](#idNeighborhood)
# 13. +*[Condition1](#idCondition1)
# 14. +*[Condition2](#idCondition2)
# 15. -*[BldgType](#idBldgType)
# 16. +*[HouseStyle](#idHouseStyle)
# 17. ++**[OverallQual](#idOverallQual)
# 18. +**[OverallCond](#idOverallCond)
# 19. ++*[YearBuilt](#idYearBuilt)
# 20. +*[YearRemodAdd](#idYearRemodAdd)
# 21. [RoofStyle](#idRoofStyle)
# 22. [RoofMatl](#idRoofMatl)
# 23. [Exterior1st](#idExterior1st)
# 24. [Exterior2nd](#idExterior2nd)
# 25. ~[MasVnrType](#idMasVnrType)-0.054 Missing
# 26. ~[MasVnrArea](#idMasVnrArea)-0.054 Missing
# 27. ++**[ExterQual](#idExterQual)
# 28. ++**[ExterCond](#idExterCond)
# 29. [Foundation](#idFoundation)
# 30. ++~[BsmtQual](#idBsmtQual)-0.02 Missing - means no basement
# 31. ++~[BsmtCond](#idBsmtCond)-0.02 Missing - means no basement
# 32. +*~[BsmtExposure](#idBsmtExposure)-0.026 missing - means no basement
# 33. +*~[BsmtFinType1](#idBsmtFinType1)-0.026 missing - means no basement
# 34. [BsmtFinSF1](#idBsmtFinSF1)-0 means no basement
# 35. ~[BsmtFinType2](#idBsmtFinType2)-0.026 missing - means no basement
# 36. [BsmtFinSF2](#idBsmtFinSF2)-0 means no basement?
# 37. [BsmtUnfSF](#idBsmtUnfSF)
# 38. ++*[TotalBsmtSF](#idTotalBsmtSF)
# 39. [Heating](#idHeating)
# 40. ++*[HeatingQC](#idHeatingQC)
# 41. ++*[CentralAir](#idCentralAir)
# 42. ~[Electrical](#idElectrical)-0.0068 missing
# 43. ++*[1stFlrSF](#id1stFlrSF)
# 44. ++*[2ndFlrSF](#id2ndFlrSF)
# 45. -*[LowQualFinSF](#idLowQualFinSF)
# 46. ++**[GrLivArea](#idGrLivArea)
# 47. -**[BsmtFullBath](#idBsmtFullBath)
# 48. -*[BsmtHalfBath](#idBsmtHalfBath)
# 49. ++*[FullBath](#idFullBath)
# 50. -*[HalfBath](#idHalfBath)
# 51. -**[BedroomAbvGr](#idBedroomAbvGr)
# 52. [KitchenAbvGr](#idKitchenAbvGr)
# 53. ++**[KitchenQual](#idKitchenQual)
# 54. +**[TotRmsAbvGrd](#idTotRmsAbvGrd)
# 55. -**[Functional](#idFunctional)
# 56. [Fireplaces](#idFireplaces)
# 57. ~[FireplaceQu](#idFireplaceQu)-0.57 missing - No firepleace
# 58. ++*~[GarageType](#idGarageType)-0.055 missing - No Garage
# 59. ~[GarageYrBlt](#idGarageYrBlt)-0.055 missing - No Garage
# 60. ++*~[GarageFinish](#idGarageFinish)-0.055 missing - No Garage
# 61. +*[GarageCars](#idGarageCars)
# 62. -*[GarageArea](#idGarageArea)
# 63. -**~[GarageQual](#idGarageQual)-0.055 missing - No Garage
# 64. -**~[GarageCond](#idGarageCond)-0.055 missing - No Garage
# 65. [PavedDrive](#idPavedDrive)
# 66. [WoodDeckSF](#idWoodDeckSF)
# 67. [OpenPorchSF](#idOpenPorchSF)
# 68. [EnclosedPorch](#idEnclosedPorch)
# 69. [3SsnPorch](#id3SsnPorch)
# 70. [PoolArea](#idPoolArea)
# 71. ~[PoolQC](#idPoolQC)-0.99 missing value
# 72. ~[Fence](#idFence)-0.80 missing value
# 73. ~[MiscFeature](#idMiscFeature)-0.96 missing value
# 74. -*[MiscVal](#idMiscVal)
# 75. [MoSold](#idMoSold)
# 76. [YrSold](#idYrSold)
# 77. ++*[SaleType](#idSaleType)
# 78. ++*[SaleCondition](#idSaleCondition)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc={"figure.figsize":(9,6)})

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
nrow = data.shape[0]
ncol = data.shape[1]

# %%
def Pnull(data, col):
    return (data[col].isnull().sum()/nrow)

def data_info(data, col):
    print ('The first few records: ')
    print (data[col].head())
    print ('The percentage of null records: ')
    print (Pnull(data, col))
    
def boxplot(data, col):
    sns.boxplot(x=col, y='SalePrice', data=data)

# %% [markdown]
# <a id="idMSSubClass"></a>
#
# ## MSSubClass
#
# #### Description
#
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Should be useful because more storage might be larger?

# %%
# Some examples of the class
data["MSSubClass"].head()
# Out:
# 0    60
# 1    20
# 2    60
# 3    70
# 4    60
# Name: MSSubClass, dtype: int64

# %%
# percentage of nulls
Pnull(data, "MSSubClass")
# Out:
# 0.0

# %%
data['MSSubClass'].describe()
# Out:
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64

# %%
sns.boxplot(x="MSSubClass", y="SalePrice", data=data)

# %% [markdown]
# We can see that there are some clear relationship between "MSSubClass" and "SalePrice".

# %% [markdown]
# <a id="idMSZoning"></a>
# ## MSZoning
#
# #### Description
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# #### Segment
#
# Location
#
# #### Expectation
#
# should be very relevant because where the building is affect the pricing the most

# %%
data["MSZoning"].head()
# Out:
# 0    RL
# 1    RL
# 2    RL
# 3    RL
# 4    RL
# Name: MSZoning, dtype: object

# %%
Pnull(data, "MSZoning")
# Out:
# 0.0

# %%
sns.boxplot(x="MSZoning", y="SalePrice", data=data)

# %% [markdown]
# <a id="idLotFrontage"></a>
# ## LotFrontage
#
# #### Description
#
# Linear feet of street connected to property
#
# #### Type
#
# Float
#
# #### Segment
#
# Location
#
# #### Expectation
#
# Should be relevant because the more street connected the price should go higher

# %%
data["LotFrontage"].head()
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# Name: LotFrontage, dtype: float64

# %%
Pnull(data, "LotFrontage")
# Out:
# 0.1773972602739726

# %%
interest = pd.concat([data.loc[:,"LotFrontage"], data.loc[:,"SalePrice"]], axis=1)
plot = interest.loc[interest["LotFrontage"].notnull(), :]

sns.distplot(plot["LotFrontage"])

# %% [markdown]
# The "LotFrontage" variable is not normally distributed.

# %%
sns.jointplot(x='LotFrontage', y='SalePrice', data=plot)

# %% [markdown]
# From this graph we can see the variable "LotFrontage" has some relationship with the "SalePrice",  however, there are a few outliers that we need to look out.

# %% [markdown]
# <a id="idLotArea"></a>
# ## LotArea
#
# #### Description
#
# Lot size in square feet
#
# #### Type
#
# Float
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related

# %%
data["LotArea"].head()
# Out:
# 0     8450
# 1     9600
# 2    11250
# 3     9550
# 4    14260
# Name: LotArea, dtype: int64

# %%
Pnull(data, "LotArea")
# Out:
# 0.0

# %% [markdown]
# <a id="idStreet"></a>
# ## Street
#
# #### Description
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related

# %%
data["Street"].head()
# Out:
# 0    Pave
# 1    Pave
# 2    Pave
# 3    Pave
# 4    Pave
# Name: Street, dtype: object

# %%
Pnull(data, "Street")
# Out:
# 0.0

# %% [markdown]
# <a id="idAlley"></a>
# ## Alley
#
# #### Description
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related

# %%
data["Alley"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Alley, dtype: object

# %%
Pnull(data, "Alley")
# Out:
# 0.93767123287671228

# %%
data['Alley'].describe()
# Out:
# count       91
# unique       2
# top       Grvl
# freq        50
# Name: Alley, dtype: object

# %% [markdown]
# <a id="idLotShape"></a>
# ## LotShape
#
# #### Description
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data["LotShape"].head()
# Out:
# 0    Reg
# 1    Reg
# 2    IR1
# 3    IR1
# 4    IR1
# Name: LotShape, dtype: object

# %%
Pnull(data, "LotShape")
# Out:
# 0.0

# %%
data['LotShape'].describe()
# Out:
# count     1460
# unique       4
# top        Reg
# freq       925
# Name: LotShape, dtype: object

# %% [markdown]
# <a id="idLandContour"></a>
# ## LandContour
#
# #### Description
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# #### Type
#
# Cat
#
# #### Segment
#
# Location
#
# #### Expectation
#
# Probably have some effects on the house price.
#
# [Back to Top](#idTop)

# %%
data["LandContour"].head()
# Out:
# 0    Lvl
# 1    Lvl
# 2    Lvl
# 3    Lvl
# 4    Lvl
# Name: LandContour, dtype: object

# %%
Pnull(data,"LandContour")
# Out:
# 0.0

# %%
sns.boxplot(x='LandContour', y='SalePrice', data=data)

# %% [markdown]
# <a id="idUtilities"></a>
# ## Utilities
#
# #### Description
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Should be quite related because it is essential for people living in there.
#
# [Back to Top](#idTop)

# %%
data["Utilities"].head()
# Out:
# 0    AllPub
# 1    AllPub
# 2    AllPub
# 3    AllPub
# 4    AllPub
# Name: Utilities, dtype: object

# %%
data["Utilities"].describe()
# Out:
# count       1460
# unique         2
# top       AllPub
# freq        1459
# Name: Utilities, dtype: object

# %%
Pnull(data, "Utilities")
# Out:
# 0.0

# %%
boxplot(data, 'Utilities')

# %% [markdown]
# <a id="idLandSlope"></a>
# ## LandSlope
#
# #### Description
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Sever slope might have a negative effect.
#
# [Back to Top](#idTop)

# %%
data['LandSlope'].head()
# Out:
# 0    Gtl
# 1    Gtl
# 2    Gtl
# 3    Gtl
# 4    Gtl
# Name: LandSlope, dtype: object

# %%
Pnull(data, 'LandSlope')
# Out:
# 0.0

# %%
boxplot(data, 'LandSlope')

# %% [markdown]
# <a id="idLotConfig"></a>
# ## LotConfig
#
# #### Description
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data["LotConfig"].head()
# Out:
# 0    Inside
# 1       FR2
# 2    Inside
# 3    Corner
# 4       FR2
# Name: LotConfig, dtype: object

# %%
Pnull(data, "LotConfig")
# Out:
# 0.0

# %% [markdown]
# <a id="idNeighborhood"></a>
# ## Neighborhood
#
# #### Description
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Probably, location again
#
# [Back to Top](#idTop)

# %%
data['Neighborhood'].head()
# Out:
# 0    CollgCr
# 1    Veenker
# 2    CollgCr
# 3    Crawfor
# 4    NoRidge
# Name: Neighborhood, dtype: object

# %%
Pnull(data, 'Neighborhood')
# Out:
# 0.0

# %%
boxplot(data, 'Neighborhood')

# %% [markdown]
# <a id="idCondition1"></a>
# ## Condition1
#
# #### Description
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Should be quite relevant because the location.
#
# [Back to Top](#idTop)

# %%
data['Condition1'].head()
# Out:
# 0     Norm
# 1    Feedr
# 2     Norm
# 3     Norm
# 4     Norm
# Name: Condition1, dtype: object

# %%
Pnull(data, 'Condition1')
# Out:
# 0.0

# %%
boxplot(data, 'Condition1')

# %% [markdown]
# <a id="idCondition2"></a>
# ## Condition2
#
# #### Description
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related.
#
# [Back to Top](#idTop)

# %%
data['Condition2'].head()
# Out:
# 0    Norm
# 1    Norm
# 2    Norm
# 3    Norm
# 4    Norm
# Name: Condition2, dtype: object

# %%
Pnull(data, 'Condition2')
# Out:
# 0.0

# %%
boxplot(data,'Condition2')

# %% [markdown]
# <a id="idBldgType"></a>
# ## BldgType
#
# #### Description
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Probably related. Because of size?
#
# [Back to Top](#idTop)

# %%
data['BldgType'].head()
# Out:
# 0    1Fam
# 1    1Fam
# 2    1Fam
# 3    1Fam
# 4    1Fam
# Name: BldgType, dtype: object

# %%
Pnull(data, 'BldgType')
# Out:
# 0.0

# %%
boxplot(data,'BldgType')

# %% [markdown]
# <a id="idHouseStyle"></a>
# ## HouseStyle
#
# #### Description
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related.
#
# [Back to Top](#idTop)

# %%
data['HouseStyle'].head()
# Out:
# 0    2Story
# 1    1Story
# 2    2Story
# 3    2Story
# 4    2Story
# Name: HouseStyle, dtype: object

# %%
Pnull(data,'HouseStyle')
# Out:
# 0.0

# %%
boxplot(data, 'HouseStyle')

# %% [markdown]
# <a id="idOverallQual"></a>
# ## OverallQual
#
# #### Description
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Strong.
#
# [Back to Top](#idTop)

# %%
data['OverallQual'].head()
# Out:
# 0    7
# 1    6
# 2    7
# 3    7
# 4    8
# Name: OverallQual, dtype: int64

# %%
Pnull(data, 'OverallQual')
# Out:
# 0.0

# %%
boxplot(data, 'OverallQual')

# %% [markdown]
# <a id="idOverallCond"></a>
# ## OverallCond
#
# #### Description
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Strong
#
# [Back to Top](#idTop)

# %%
data['OverallCond'].head()
# Out:
# 0    5
# 1    8
# 2    5
# 3    5
# 4    5
# Name: OverallCond, dtype: int64

# %%
Pnull(data, 'OverallCond')
# Out:
# 0.0

# %%
boxplot(data, 'OverallCond')

# %% [markdown]
# <a id="idYearBuilt"></a>
# ## YearBuilt
#
# #### Description
#
# YearBuilt: Original construction date
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related
#
# [Back to Top](#idTop)

# %%
data['YearBuilt'].head()
# Out:
# 0    2003
# 1    1976
# 2    2001
# 3    1915
# 4    2000
# Name: YearBuilt, dtype: int64

# %%
Pnull(data, 'YearBuilt')
# Out:
# 0.0

# %%
sns.regplot(x='YearBuilt', y="SalePrice", data=data)

# %% [markdown]
# <a id="idYearRemodAdd"></a>
# ## YearRemodAdd
#
# #### Description
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related
#
# [Back to Top](#idTop)

# %%
data['YearRemodAdd'].head()
# Out:
# 0    2003
# 1    1976
# 2    2002
# 3    1970
# 4    2000
# Name: YearRemodAdd, dtype: int64

# %%
Pnull(data, 'YearRemodAdd')
# Out:
# 0.0

# %%
sns.regplot(x='YearBuilt', y="SalePrice", data=data)

# %% [markdown]
# <a id="idRoofStyle"></a>
# ## RoofStyle
#
# #### Description
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['RoofStyle'].head()
# Out:
# 0    Gable
# 1    Gable
# 2    Gable
# 3    Gable
# 4    Gable
# Name: RoofStyle, dtype: object

# %%
Pnull(data, 'RoofStyle')
# Out:
# 0.0

# %% [markdown]
# <a id="idRoofMatl"></a>
# ## RoofMatl
#
# #### Description
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['RoofMatl'].head()
# Out:
# 0    CompShg
# 1    CompShg
# 2    CompShg
# 3    CompShg
# 4    CompShg
# Name: RoofMatl, dtype: object

# %%
Pnull(data, 'RoofMatl')
# Out:
# 0.0

# %% [markdown]
# <a id="idExterior1st"></a>
# ## Exterior1st
#
# #### Description
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Might be. The look of the house?
#
# [Back to Top](#idTop)

# %%
data['Exterior1st'].head()
# Out:
# 0    VinylSd
# 1    MetalSd
# 2    VinylSd
# 3    Wd Sdng
# 4    VinylSd
# Name: Exterior1st, dtype: object

# %%
Pnull(data, 'Exterior1st')
# Out:
# 0.0

# %% [markdown]
# <a id="idExterior2nd"></a>
# ## Exterior2nd
#
# #### Description
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# A little. The look of the house from outside?
#
# [Back to Top](#idTop)

# %%
data['Exterior2nd'].head()
# Out:
# 0    VinylSd
# 1    MetalSd
# 2    VinylSd
# 3    Wd Shng
# 4    VinylSd
# Name: Exterior2nd, dtype: object

# %%
Pnull(data, 'Exterior2nd')
# Out:
# 0.0

# %% [markdown]
# <a id="idMasVnrType"></a>
# ## MasVnrType
#
# #### Description
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
# External brick material?
#
# [Back to Top](#idTop)

# %%
data['MasVnrType'].head()
# Out:
# 0    BrkFace
# 1       None
# 2    BrkFace
# 3       None
# 4    BrkFace
# Name: MasVnrType, dtype: object

# %%
data['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
Pnull(data, 'MasVnrType')
# Out:
# 0.0054794520547945206

# %% [markdown]
# <a id="idMasVnrArea"></a>
# ## MasVnrArea
#
# #### Description
#
# MasVnrArea: Masonry veneer area in square feet
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['MasVnrArea'].head()
# Out:
# 0    196.0
# 1      0.0
# 2    162.0
# 3      0.0
# 4    350.0
# Name: MasVnrArea, dtype: float64

# %%
Pnull(data, 'MasVnrArea')
# Out:
# 0.0054794520547945206

# %% [markdown]
# <a id="idExterQual"></a>
# ## ExterQual
#
# #### Description
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Might be very related.
#
# [Back to Top](#idTop)

# %%
data['ExterQual'].head()
# Out:
# 0    Gd
# 1    TA
# 2    Gd
# 3    TA
# 4    Gd
# Name: ExterQual, dtype: object

# %%
Pnull(data, 'ExterQual')
# Out:
# 0.0

# %%
boxplot(data, 'ExterQual')

# %% [markdown]
# <a id="idExterCond"></a>
# ## ExterCond
#
# #### Description
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Might be quite
#
# [Back to Top](#idTop)

# %%
data['ExterCond'].head()
# Out:
# 0    TA
# 1    TA
# 2    TA
# 3    TA
# 4    TA
# Name: ExterCond, dtype: object

# %%
Pnull(data, 'ExterCond')
# Out:
# 0.0

# %%
boxplot(data, 'ExterCond')

# %% [markdown]
# <a id="idFoundation"></a>
# ## Foundation
#
# #### Description
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['Foundation'].head()
# Out:
# 0     PConc
# 1    CBlock
# 2     PConc
# 3    BrkTil
# 4     PConc
# Name: Foundation, dtype: object

# %%
Pnull(data, 'Foundation')
# Out:
# 0.0

# %%
boxplot(data, 'Foundation')

# %% [markdown]
# <a id="idBsmtQual"></a>
# ## BsmtQual
#
# #### Description
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Might be related.
#
# [Back to Top](#idTop)

# %%
data['BsmtQual'].head()
# Out:
# 0    Gd
# 1    Gd
# 2    Gd
# 3    TA
# 4    Gd
# Name: BsmtQual, dtype: object

# %%
data['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
Pnull(data, 'BsmtQual')
# Out:
# 0.025342465753424658

# %%
data.loc[data['BsmtQual'].isnull(), 'BsmtQual'] = 'NA'

# %%
boxplot(data, 'BsmtQual')

# %% [markdown]
# <a id="idBsmtCond"></a>
# ## BsmtCond
#
# #### Description
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['BsmtCond'].head()
# Out:
# 0    TA
# 1    TA
# 2    TA
# 3    Gd
# 4    TA
# Name: BsmtCond, dtype: object

# %%
data['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object)

# %%
Pnull(data, 'BsmtCond')
# Out:
# 0.025342465753424658

# %%
data.loc[data['BsmtCond'].isnull(), 'BsmtCond'] = 'NA'

# %%
boxplot(data, 'BsmtCond')

# %% [markdown]
# <a id="idBsmtExposure"></a>
# ## BsmtExposure
#
# #### Description
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['BsmtExposure'].head()
# Out:
# 0    No
# 1    Gd
# 2    Mn
# 3    No
# 4    Av
# Name: BsmtExposure, dtype: object

# %%
data['BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
Pnull(data, 'BsmtExposure')
# Out:
# 0.026027397260273973

# %%
data.loc[data['BsmtExposure'].isnull(), 'BsmtExposure'] = 'NA'

# %%
boxplot(data,'BsmtExposure')

# %% [markdown]
# <a id="idBsmtFinType1"></a>
# ## BsmtFinType1
#
# #### Description
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
# Somewhat related.
#
# [Back to Top](#idTop)

# %%
data['BsmtFinType1'].head()
# Out:
# 0    GLQ
# 1    ALQ
# 2    GLQ
# 3    ALQ
# 4    GLQ
# Name: BsmtFinType1, dtype: object

# %%
data['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ'], dtype=object)

# %%
Pnull(data, 'BsmtFinType1')
# Out:
# 0.025342465753424658

# %%
data.loc[data['BsmtFinType1'].isnull(), 'BsmtFinType1'] = 'NA'

# %%
boxplot(data, 'BsmtFinType1')

# %% [markdown]
# <a id="idBsmtFinSF1"></a>
# ## BsmtFinSF1
#
# #### Description
#
# BsmtFinSF1: Type 1 finished square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related
#
# [Back to Top](#idTop)

# %%
data['BsmtFinSF1'].head()
# Out:
# 0    706
# 1    978
# 2    486
# 3    216
# 4    655
# Name: BsmtFinSF1, dtype: int64

# %%
Pnull(data, 'BsmtFinSF1')
# Out:
# 0.0

# %%
sns.regplot(x='BsmtFinSF1', y='SalePrice', data=data)

# %% [markdown]
# Some kind of trend there. But there is a outlier.

# %% [markdown]
# <a id="idBsmtFinType2"></a>
# ## BsmtFinType2
#
# #### Description
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['BsmtFinType2'].head()
# Out:
# 0    Unf
# 1    Unf
# 2    Unf
# 3    Unf
# 4    Unf
# Name: BsmtFinType2, dtype: object

# %%
Pnull(data, 'BsmtFinType2')
# Out:
# 0.026027397260273973

# %% [markdown]
# <a id="idBsmtFinSF2"></a>
# ## BsmtFinSF2
#
# #### Description
#
# BsmtFinSF2: Type 2 finished square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Same as above.
#
# [Back to Top](#idTop)

# %%
data['BsmtFinSF2'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: BsmtFinSF2, dtype: int64

# %%
data['BsmtFinSF2'].unique()
# Out:
# array([   0,   32,  668,  486,   93,  491,  506,  712,  362,   41,  169,
#         869,  150,  670,   28, 1080,  181,  768,  215,  374,  208,  441,
#         184,  279,  306,  180,  580,  690,  692,  228,  125, 1063,  620,
#         175,  820, 1474,  264,  479,  147,  232,  380,  544,  294,  258,
#         121,  391,  531,  344,  539,  713,  210,  311, 1120,  165,  532,
#          96,  495,  174, 1127,  139,  202,  645,  123,  551,  219,  606,
#         612,  480,  182,  132,  336,  468,  287,   35,  499,  723,  119,
#          40,  117,  239,   80,  472,   64, 1057,  127,  630,  128,  377,
#         764,  345, 1085,  435,  823,  500,  290,  324,  634,  411,  841,
#        1061,  466,  396,  354,  149,  193,  273,  465,  400,  682,  557,
#         230,  106,  791,  240,  547,  469,  177,  108,  600,  492,  211,
#         168, 1031,  438,  375,  144,   81,  906,  608,  276,  661,   68,
#         173,  972,  105,  420,  546,  334,  352,  872,  110,  627,  163,
#        1029])

# %%
Pnull(data, 'BsmtFinSF2')
# Out:
# 0.0

# %% [markdown]
# <a id="idBsmtUnfSF"></a>
# ## BsmtUnfSF
#
# #### Description
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['BsmtUnfSF'].head()
# Out:
# 0    150
# 1    284
# 2    434
# 3    540
# 4    490
# Name: BsmtUnfSF, dtype: int64

# %%
Pnull(data, 'BsmtUnfSF')
# Out:
# 0.0

# %% [markdown]
# <a id="idTotalBsmtSF"></a>
# ## TotalBsmtSF
#
# #### Description
#
# TotalBsmtSF: Total square feet of basement area
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related.
#
# [Back to Top](#idTop)

# %%
data['TotalBsmtSF'].head()
# Out:
# 0     856
# 1    1262
# 2     920
# 3     756
# 4    1145
# Name: TotalBsmtSF, dtype: int64

# %%
Pnull(data, 'TotalBsmtSF')
# Out:
# 0.0

# %%
data.plot.scatter(x='TotalBsmtSF', y='SalePrice')

# %% [markdown]
# Strong relationship but there is a outlier.

# %% [markdown]
# <a id="idHeating"></a>
# ## Heating
#
# #### Description
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['Heating'].head()
# Out:
# 0    GasA
# 1    GasA
# 2    GasA
# 3    GasA
# 4    GasA
# Name: Heating, dtype: object

# %%
Pnull(data, "Heating")
# Out:
# 0.0

# %% [markdown]
# <a id="idHeatingQC"></a>
# ## HeatingQC
#
# #### Description
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related
#
# [Back to Top](#idTop)

# %%
data['HeatingQC'].head()
# Out:
# 0    Ex
# 1    Ex
# 2    Ex
# 3    Gd
# 4    Ex
# Name: HeatingQC, dtype: object

# %%
Pnull(data, 'HeatingQC')
# Out:
# 0.0

# %%
boxplot(data, 'HeatingQC')

# %% [markdown]
# <a id="idCentralAir"></a>
# ## CentralAir
#
# #### Description
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related.
#
# [Back to Top](#idTop)

# %%
data['CentralAir'].head()
# Out:
# 0    Y
# 1    Y
# 2    Y
# 3    Y
# 4    Y
# Name: CentralAir, dtype: object

# %%
Pnull(data, 'CentralAir')
# Out:
# 0.0

# %%
boxplot(data, 'CentralAir')

# %% [markdown]
# <a id="idElectrical"></a>
# ## Electrical
#
# #### Description
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not related
#
# [Back to Top](#idTop)

# %%
data['Electrical'].head()
# Out:
# 0    SBrkr
# 1    SBrkr
# 2    SBrkr
# 3    SBrkr
# 4    SBrkr
# Name: Electrical, dtype: object

# %%
data['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
Pnull(data, 'Electrical')
# Out:
# 0.00068493150684931507

# %% [markdown]
# <a id="id1stFlrSF"></a>
# ## 1stFlrSF
#
# #### Description
#
# 1stFlrSF: First Floor square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['1stFlrSF'].head()
# Out:
# 0     856
# 1    1262
# 2     920
# 3     961
# 4    1145
# Name: 1stFlrSF, dtype: int64

# %%
Pnull(data, '1stFlrSF')
# Out:
# 0.0

# %%
data.plot.scatter(x='1stFlrSF', y='SalePrice')

# %% [markdown]
# <a id="id2ndFlrSF"></a>
# ## 2ndFlrSF
#
# #### Description
#
# 2ndFlrSF: Second floor square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related
#
# [Back to Top](#idTop)

# %%
data['2ndFlrSF'].head()
# Out:
# 0     854
# 1       0
# 2     866
# 3     756
# 4    1053
# Name: 2ndFlrSF, dtype: int64

# %%
Pnull(data, '2ndFlrSF')
# Out:
# 0.0

# %%
data.plot.scatter(x='2ndFlrSF', y='SalePrice')

# %% [markdown]
# An interesting variable. The houses with no second floor will are zero. The 2nd floow area actually have a very strong indication of sale price.

# %% [markdown]
# <a id="idLowQualFinSF"></a>
# ## LowQualFinSF
#
# #### Description
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related
#
# [Back to Top](#idTop)

# %%
data['LowQualFinSF'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: LowQualFinSF, dtype: int64

# %%
Pnull(data,'LowQualFinSF')
# Out:
# 0.0

# %%
data.plot.scatter(x='LowQualFinSF', y='SalePrice')

# %% [markdown]
# <a id="idGrLivArea"></a>
# ## GrLivArea
#
# #### Description
#
# GrLivArea: Above grade (ground) living area square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['GrLivArea'].head()
# Out:
# 0    1710
# 1    1262
# 2    1786
# 3    1717
# 4    2198
# Name: GrLivArea, dtype: int64

# %%
Pnull(data, "GrLivArea")
# Out:
# 0.0

# %%
data.plot.scatter(x='GrLivArea', y='SalePrice')

# %% [markdown]
# A very good one but have some outliers that we need to inspect

# %% [markdown]
# <a id="idBsmtFullBath"></a>
# ## BsmtFullBath
#
# #### Description
#
# BsmtFullBath: Basement full bathrooms
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Should be quite related
#
# [Back to Top](#idTop)

# %%
data["BsmtFullBath"].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: BsmtFullBath, dtype: int64

# %%
Pnull(data, 'BsmtFullBath')
# Out:
# 0.0

# %%
data.plot.scatter(x='BsmtFullBath', y='SalePrice')

# %% [markdown]
# <a id="idBsmtHalfBath"></a>
# ## BsmtHalfBath
#
# #### Description
#
# BsmtHalfBath: Basement half bathrooms
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somwhat related?
#
# [Back to Top](#idTop)

# %%
data['BsmtHalfBath'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: BsmtHalfBath, dtype: int64

# %%
Pnull(data,'BsmtHalfBath')
# Out:
# 0.0

# %% [markdown]
# <a id="idFullBath"></a>
# ## FullBath
#
# #### Description
#
# FullBath: Full bathrooms above grade
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Should be very related
#
# [Back to Top](#idTop)

# %%
data['FullBath'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    1
# 4    2
# Name: FullBath, dtype: int64

# %%
Pnull(data, 'FullBath')
# Out:
# 0.0

# %%
data.plot.scatter(x='FullBath', y='SalePrice')

# %% [markdown]
# <a id="idHalfBath"></a>
# ## HalfBath
#
# #### Description
#
# HalfBath: Half baths above grade
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# somewhat related
#
# [Back to Top](#idTop)

# %%
data['HalfBath'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: HalfBath, dtype: int64

# %%
Pnull(data, 'HalfBath')
# Out:
# 0.0

# %%
data.plot.scatter(x='HalfBath', y='SalePrice')

# %% [markdown]
# <a id="idBedroomAbvGr"></a>
# ## BedroomAbvGr
#
# #### Description
#
# BedroomAbvGr: Bedrooms above grade (does NOT include basement bedrooms)
#
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# very strong
#
# [Back to Top](#idTop)

# %%
data['BedroomAbvGr'].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# Name: BedroomAbvGr, dtype: int64

# %%
Pnull(data, 'BedroomAbvGr')
# Out:
# 0.0

# %%
data.plot.scatter(x='BedroomAbvGr', y='SalePrice')

# %% [markdown]
# <a id="idKitchenAbvGr"></a>
# ## KitchenAbvGr
#
# #### Description
#
# KitchenAbvGr: Kitchens above grade
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['KitchenAbvGr'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: KitchenAbvGr, dtype: int64

# %%
Pnull(data,'KitchenAbvGr')
# Out:
# 0.0

# %% [markdown]
# <a id="idKitchenQual"></a>
# ## KitchenQual
#
# #### Description
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Strongly related
#
# [Back to Top](#idTop)

# %%
data['KitchenQual'].head()
# Out:
# 0    Gd
# 1    TA
# 2    Gd
# 3    Gd
# 4    Gd
# Name: KitchenQual, dtype: object

# %%
Pnull(data, 'KitchenQual')
# Out:
# 0.0

# %%
boxplot(data, 'KitchenQual')

# %% [markdown]
# <a id="idTotRmsAbvGrd"></a>
# ## TotRmsAbvGrd
#
# #### Description
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Strongly related
#
# [Back to Top](#idTop)

# %%
data['TotRmsAbvGrd'].head()
# Out:
# 0    8
# 1    6
# 2    6
# 3    7
# 4    9
# Name: TotRmsAbvGrd, dtype: int64

# %%
Pnull(data, 'TotRmsAbvGrd')
# Out:
# 0.0

# %%
data.plot.scatter(x='TotRmsAbvGrd', y='SalePrice')

# %% [markdown]
# <a id="idFunctional"></a>
# ## Functional
#
# #### Description
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Strongly related
#
# [Back to Top](#idTop)

# %%
data['Functional'].head()
# Out:
# 0    Typ
# 1    Typ
# 2    Typ
# 3    Typ
# 4    Typ
# Name: Functional, dtype: object

# %%
Pnull(data, 'Functional')
# Out:
# 0.0

# %%
boxplot(data, 'Functional')

# %% [markdown]
# <a id="idFireplaces"></a>
# ## Fireplaces
#
# #### Description
#
# Fireplaces: Number of fireplaces
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['Fireplaces'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Fireplaces, dtype: int64

# %%
Pnull(data,'Fireplaces')
# Out:
# 0.0

# %% [markdown]
# <a id="idFireplaceQu"></a>
# ## FireplaceQu
#
# #### Description
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['FireplaceQu'].head()
# Out:
# 0    NaN
# 1     TA
# 2     TA
# 3     Gd
# 4     TA
# Name: FireplaceQu, dtype: object

# %%
Pnull(data, 'FireplaceQu')
# Out:
# 0.4726027397260274

# %% [markdown]
# <a id="idGarageType"></a>
# ## GarageType
#
# #### Description
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['GarageType'].head()
# Out:
# 0    Attchd
# 1    Attchd
# 2    Attchd
# 3    Detchd
# 4    Attchd
# Name: GarageType, dtype: object

# %%
Pnull(data, 'GarageType')
# Out:
# 0.055479452054794522

# %%
boxplot(data,'GarageType')

# %% [markdown]
# <a id="idGarageYrBlt"></a>
# ## GarageYrBlt
#
# #### Description
#
# GarageYrBlt: Year garage was built
#
# #### Type
#
# float
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['GarageYrBlt'].head()
# Out:
# 0    2003.0
# 1    1976.0
# 2    2001.0
# 3    1998.0
# 4    2000.0
# Name: GarageYrBlt, dtype: float64

# %%
Pnull(data, 'GarageYrBlt')
# Out:
# 0.055479452054794522

# %% [markdown]
# <a id="idGarageFinish"></a>
# ## GarageFinish
#
# #### Description
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['GarageFinish'].head()
# Out:
# 0    RFn
# 1    RFn
# 2    RFn
# 3    Unf
# 4    RFn
# Name: GarageFinish, dtype: object

# %%
Pnull(data,'GarageFinish')
# Out:
# 0.055479452054794522

# %%
boxplot(data,'GarageFinish')

# %% [markdown]
# <a id="idGarageCars"></a>
# ## GarageCars
#
# #### Description
#
# GarageCars: Size of garage in car capacity
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related.
#
# [Back to Top](#idTop)

# %%
data['GarageCars'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    3
# 4    3
# Name: GarageCars, dtype: int64

# %%
Pnull(data, 'GarageCars')
# Out:
# 0.0

# %%
data.plot.scatter(x='GarageCars', y='SalePrice')

# %% [markdown]
# <a id="idGarageArea"></a>
# ## GarageArea
#
# #### Description
#
# GarageArea: Size of garage in square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data['GarageArea'].head()
# Out:
# 0    548
# 1    460
# 2    608
# 3    642
# 4    836
# Name: GarageArea, dtype: int64

# %%
Pnull(data, 'GarageArea')
# Out:
# 0.0

# %%
data.plot.scatter(x='GarageArea', y='SalePrice')

# %% [markdown]
# <a id="idGarageQual"></a>
# ## GarageQual
#
# #### Description
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Strong relation
#
# [Back to Top](#idTop)

# %%
data['GarageQual'].head()
# Out:
# 0    TA
# 1    TA
# 2    TA
# 3    TA
# 4    TA
# Name: GarageQual, dtype: object

# %%
data['GarageQual'].unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object)

# %%
Pnull(data, 'GarageQual')
# Out:
# 0.055479452054794522

# %%
boxplot(data,'GarageQual')

# %% [markdown]
# <a id="idGarageCond"></a>
# ## GarageCond
#
# #### Description
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Strong relation
#
# [Back to Top](#idTop)

# %%
data['GarageCond'].head()
# Out:
# 0    TA
# 1    TA
# 2    TA
# 3    TA
# 4    TA
# Name: GarageCond, dtype: object

# %%
Pnull(data, 'GarageCond')
# Out:
# 0.055479452054794522

# %%
boxplot(data,'GarageCond')

# %% [markdown]
# <a id="idPavedDrive"></a>
# ## PavedDrive
#
# #### Description
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'PavedDrive')
# Out:
# The first few records:
# 0    Y
# 1    Y
# 2    Y
# 3    Y
# 4    Y
# Name: PavedDrive, dtype: object
# The percentage of null records:
# 0.0

# %% [markdown]
# <a id="idWoodDeckSF"></a>
# ## WoodDeckSF
#
# #### Description
#
# WoodDeckSF: Wood deck area in square feet
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# might be related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'WoodDeckSF')
# Out:
# The first few records:
# 0      0
# 1    298
# 2      0
# 3      0
# 4    192
# Name: WoodDeckSF, dtype: int64
# The percentage of null records:
# 0.0

# %% [markdown]
# <a id="idOpenPorchSF"></a>
# ## OpenPorchSF
#
# #### Description
#
# OpenPorchSF: Open porch area in square feet
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'OpenPorchSF')
# Out:
# The first few records:
# 0    61
# 1     0
# 2    42
# 3    35
# 4    84
# Name: OpenPorchSF, dtype: int64
# The percentage of null records:
# 0.0

# %% [markdown]
# <a id="idEnclosedPorch"></a>
# ## EnclosedPorch
#
# #### Description
#
# EnclosedPorch: Enclosed porch area in square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'EnclosedPorch')
# Out:
# The first few records:
# 0      0
# 1      0
# 2      0
# 3    272
# 4      0
# Name: EnclosedPorch, dtype: int64
# The percentage of null records:
# 0.0

# %% [markdown]
# <a id="id3SsnPorch"></a>
# ## 3SsnPorch
#
# #### Description
#
# 3SsnPorch: Three season porch area in square feet
#
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, '3SsnPorch')
# Out:
# The first few records:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: 3SsnPorch, dtype: int64
# The percentage of null records:
# 0.0

# %%
Pnull(data, '3SsnPorch')
# Out:
# 0.0

# %% [markdown]
# <a id="idPoolArea"></a>
# ## PoolArea
#
# #### Description
#
# PoolArea: Pool area in square feet
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'PoolArea')
# Out:
# The first few records:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: PoolArea, dtype: int64
# The percentage of null records:
# 0.0

# %% [markdown]
# <a id="idPoolQC"></a>
# ## PoolQC
#
# #### Description
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'PoolQC')
# Out:
# The first few records:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: PoolQC, dtype: object
# The percentage of null records:
# 0.995205479452

# %% [markdown]
# <a id="idFence"></a>
# ## Fence
#
# #### Description
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data,'Fence')
# Out:
# The first few records:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Fence, dtype: object
# The percentage of null records:
# 0.807534246575

# %% [markdown]
# <a id="idMiscFeature"></a>
# ## MiscFeature
#
# #### Description
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data,'MiscFeature')
# Out:
# The first few records:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: MiscFeature, dtype: object
# The percentage of null records:
# 0.96301369863

# %% [markdown]
# <a id="idMiscVal"></a>
# ## MiscVal
#
# #### Description
#
# MiscVal: $Value of miscellaneous feature
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related
#
# [Back to Top](#idTop)

# %%
data_info(data,'MiscVal')
# Out:
# The first few records:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: MiscVal, dtype: int64
# The percentage of null records:
# 0.0

# %%
data['MiscVal'].unique()
# Out:
# array([    0,   700,   350,   500,   400,   480,   450, 15500,  1200,
#          800,  2000,   600,  3500,  1300,    54,   620,   560,  1400,
#         8300,  1150,  2500])

# %%
data.plot.scatter(x='MiscVal', y='SalePrice')

# %% [markdown]
# <a id="idMoSold"></a>
# ## MoSold
#
# #### Description
#
# MoSold: Month Sold (MM)
#
# #### Type
#
# int
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'MoSold')
# Out:
# The first few records:
# 0     2
# 1     5
# 2     9
# 3     2
# 4    12
# Name: MoSold, dtype: int64
# The percentage of null records:
# 0.0

# %% [markdown]
# <a id="idYrSold"></a>
# ## YrSold
#
# #### Description
#
# YrSold: Year Sold (YYYY)
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Not so related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'YrSold')
# Out:
# The first few records:
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
# Name: YrSold, dtype: int64
# The percentage of null records:
# 0.0

# %% [markdown]
# <a id="idSaleType"></a>
# ## SaleType
#
# #### Description
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Somewhat related.
#
# [Back to Top](#idTop)

# %%
data_info(data,'SaleType')
# Out:
# The first few records:
# 0    WD
# 1    WD
# 2    WD
# 3    WD
# 4    WD
# Name: SaleType, dtype: object
# The percentage of null records:
# 0.0

# %%
boxplot(data,'SaleType')

# %% [markdown]
# <a id="idSaleCondition"></a>
# ## SaleCondition
#
# #### Description
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)
#
# #### Type
#
# Cat
#
# #### Segment
#
# Structure
#
# #### Expectation
#
# Might be related
#
# [Back to Top](#idTop)

# %%
data_info(data, 'SaleCondition')
# Out:
# The first few records:
# 0     Normal
# 1     Normal
# 2     Normal
# 3    Abnorml
# 4     Normal
# Name: SaleCondition, dtype: object
# The percentage of null records:
# 0.0

# %%
boxplot(data,'SaleCondition')
